# %% [markdown]
# # <font color=#BB44>Python Introduction (MSTC)</font>
#
# ## [NumPy is the fundamental package for scientific computing with Python](http://www.numpy.org/)
# ![Imagen Numpy](http://www.numpy.org/_static/numpy_logo.png)
#
# ## [Matplotlib is a Python 2D plotting library](https://matplotlib.org/)
# ![Matplotlib Image](https://matplotlib.org/_static/logo2.png)
#
# ## [Python Data Analysis Library](https://pandas.pydata.org/)
# ![Pandas Image](https://pandas.pydata.org/_static/pandas_logo.png)
#
# ## [scikit-learn: Machine Learning in Python](http://scikit-learn.org/stable/)
# ![Scikit-learn Image](http://scikit-learn.org/stable/_static/scikit-learn-logo-small.png)

# %% [markdown]
# ---
#
# ## First: Download data from a web site  (for example MSTC GitHub)

# %%
! wget -q -N https://raw.githubusercontent.com/MasterMSTC/Python-Introduction/master/OSA_DB_UPM.csv
# Out:
# Redirecting output to ‘wget-log’.

# %%
! ls
# Out:
# OSA_DB_UPM.csv	sample_data  wget-log

# %% [markdown]
# ### .... read this file in a list of lists : OSA_Table

# %%
file = open('OSA_DB_UPM.csv','r')

OSA_Table=[]

# %%
header=file.readline()
print('Header: ',header.split(';'))
# Out:
# Header:  ['Gender', 'IAH', 'Weight', 'Height', 'Age', 'Cervical\n']

# %%
for line in file:
  if not (line.find(';;')!=-1 or line.find('-1')!=-1):
    OSA_Table.append(line.replace(',', '.').rstrip().split(';'))
  
file.close
# Out:
# <function TextIOWrapper.close>

# %%
import numpy as np

OSA_matrix=np.float_(OSA_Table)

# %%
OSA_matrix.shape
# Out:
# (599, 6)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(OSA_matrix[:,1],OSA_matrix[:,2])
plt.xlabel('AHI')
plt.ylabel('Weight')
# Out:
# Text(0,0.5,'Weight')

# %%
plt.hist(OSA_matrix[:,2])
# Out:
# (array([  9.,  71., 158., 152., 111.,  55.,  24.,  11.,   4.,   4.]),
#  array([ 45.,  57.,  69.,  81.,  93., 105., 117., 129., 141., 153., 165.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Using Pandas DataFrames

# %%
import pandas as pd

# %%
OSA_df = pd.read_csv("OSA_DB_UPM.csv",sep=';',na_values=['-1',''])

# %%
OSA_df.head(5)
# Out:
#    Gender   IAH  Weight  Height   Age  Cervical
# 0       0  71.0    82.0   168.0  39.0       NaN
# 1       0  29.6   119.0   174.0  56.0      48.0
# 2       0  56.0     NaN     NaN  46.0      43.0
# 3       0  19.7    78.0   168.0  39.0      42.0
# 4       0   9.0    80.0   173.0  32.0      40.0

# %%
OSA_df.dtypes
# Out:
# Gender        int64
# IAH         float64
# Weight      float64
# Height      float64
# Age         float64
# Cervical    float64
# dtype: object

# %%
OSA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
# Gender      617 non-null int64
# IAH         607 non-null float64
# Weight      616 non-null float64
# Height      616 non-null float64
# Age         614 non-null float64
# Cervical    610 non-null float64
# dtypes: float64(5), int64(1)
# memory usage:
A_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599 entries, 1 to 616
# Data columns (total 6 columns):
# Gender      599 non-null int64
# IAH         599 non-null float64
# Weight      599 non-null float64
# Height      599 non-null float64
# Age         599 non-null float64
# Cervical    599 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 32.8 KB

# %%
OSA_df.describe()
# Out:
#            Gender         IAH      Weight      Height         Age    Cervical
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     0.285476   20.147346   87.704508  171.168614   49.502504   40.631886
# std      0.452018   18.144753   18.412257    9.502857   12.349546    3.969171
# min      0.000000    0.000000   45.000000  144.000000   20.000000   30.000000
# 25%      0.000000    6.400000   75.000000  165.000000   40.000000   38.000000
# 50%      0.000000   14.300000   86.000000  171.000000   49.000000   41.000000
# 75%      1.000000   30.000000   98.000000  178.000000   59.000000   43.000000
# max      1.000000  108.400000  165.000000  197.000000   88.000000   53.000000

# %%
OSA_df.index

# %%
plt.scatter(OSA_df['IAH'],OSA_df['Weight'])

# %%
OSA_df['IAH'].plot()

# %%
OSA_df['IAH'].hist()

# .describe()   .mean()

# %%
axes = pd.tools.plotting.scatter_matrix(OSA_df, alpha=0.6, figsize=(12, 8), diagonal='hist')

# diaginal = 'kde'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## [scikit-learn: Machine Learning in Python](http://scikit-learn.org/stable/)
# ![Scikit-learn Image](http://scikit-learn.org/stable/_static/scikit-learn-logo-small.png)

# %% [markdown]
# ## Python ML <font color='blue'>sklearn</font> for Multiple Linear Regression

# %%
OSA_df=OSA_df.dropna()

# %%
### Picking predictor columns

# Get all the columns from the dataframe.
columns = OSA_df.columns.tolist()

# Filter the columns to remove ones we don't want.
columns = [c for c in columns if c not in ["IAH","Gender"]]

# Store the variable we'll be predicting on.
target = "IAH"

print('Predictors: ',columns)
# Out:
# Predictors:  ['Weight', 'Height', 'Age', 'Cervical']

# %%
# Splitting into train and test sets

# Generate the training set.  Set random_state to be able to replicate results.
train = OSA_df.sample(frac=0.8, random_state=1)


# Select anything not in the training set and put it in the testing set.
test = OSA_df.loc[~OSA_df.index.isin(train.index)]

# Print the shapes of both sets.
print(train.shape)
print(test.shape)
# Out:
# (479, 6)
# (120, 6)

# %% [markdown]
# ## TRAIN:

# %%
# Fitting a linear regression

# Import the linear models.
from sklearn import linear_model

# Initialize the model class.

model= linear_model.LinearRegression()

#model= linear_model.Ridge(alpha = 0.5)
# Fit the model to the training data.
Trained_model=model.fit(train[columns], train[target])

# %% [markdown]
# ## Test

# %%
### Predicting Error

# Import the scikit-learn function to compute error.
from sklearn.metrics import mean_squared_error

# Generate our predictions for the test set.
predictions = model.predict(test[columns])

# Compute error between our test predictions and the actual values.
MSE=mean_squared_error(predictions, test[target])

print('Mean squared Error: ', MSE)
# Out:
# Mean squared Error:  323.88180208070895

# %%
# Explained variance score: 
from sklearn.metrics import r2_score

print('Variance score: %.2f' % r2_score(test[target], predictions))
# Out:
# Variance score: 0.14

# %%
# Plot outputs
plt.scatter(test[target], predictions,  color='red')

plt.show()

# %% [markdown]
# ## Try improve using "feature" engineering ...  BMI, ....  (log(AHI))
