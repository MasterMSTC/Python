# %% [markdown]
# ## mu, sigma = 0, 0.1 # mean and standard deviation

# %%
import numpy as np

x=np.random.normal(0,1,1000)
#x=np.random.rand(1000)

# %%
print("Mean = " , np.mean(x),  ' Std = ', np.std(x))
# Out:
# Mean =  0.499604507149  Std =  0.282270673683

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x)

# %%
plt.hist(x,20)
# Out:
# (array([ 47.,  42.,  51.,  58.,  46.,  53.,  45.,  47.,  43.,  55.,  47.,
#          63.,  59.,  62.,  56.,  41.,  51.,  52.,  32.,  50.]),
#  array([  9.54561955e-05,   5.00284877e-02,   9.99615193e-02,
#           1.49894551e-01,   1.99827582e-01,   2.49760614e-01,
#           2.99693646e-01,   3.49626677e-01,   3.99559709e-01,
#           4.49492740e-01,   4.99425772e-01,   5.49358803e-01,
#           5.99291835e-01,   6.49224866e-01,   6.99157898e-01,
#           7.49090929e-01,   7.99023961e-01,   8.48956993e-01,
#           8.98890024e-01,   9.48823056e-01,   9.98756087e-01]),
#  <a list of 20 Patch objects>)
